# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
extended_train_features = pd.read_csv('extended_train_features.csv')
extended_train_labels = pd.read_csv('extended_train_labels.csv')
extended_train_features.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906        0.200000        0.341275        0.970637
# 1        28830        0.266667        0.630694        0.223761
# 2        94947        0.700000        0.254380        0.714013
# 3       590882        0.733333        0.292922        0.850959
# 4       201944        0.366667        0.091801        0.118405
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2  0.3         0.050505           0.100000
# 1                    2  0.1         0.070707           0.166667
# 2                    2  0.1         0.040404           0.100000
# 3                    2  0.1         0.050505           0.100000
# 4                    3  0.3         0.070707           0.233333
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             1                                    1  ...
# ...

# %% [markdown]
# ### Equilibrated, smaller sample

# %%
#index = np.random.choice(len(extended_train_features), 5000, replace=False)

# Remove building id
exclude = ['building_id']
features = extended_train_features.loc[:,[i for i in list(extended_train_features.columns) if i not in exclude]]
features.head()
# features = np.asarray(features)#[index]

# labels = extended_train_labels['damage_grade']
# labels = np.asarray(labels)#[index]
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0        0.200000        0.341275        0.970637                    2  0.3
# 1        0.266667        0.630694        0.223761                    2  0.1
# 2        0.700000        0.254380        0.714013                    2  0.1
# 3        0.733333        0.292922        0.850959                    2  0.1
# 4        0.366667        0.091801        0.118405                    3  0.3
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0         0.050505           0.100000                             1
# 1         0.070707           0.166667                             0
# 2         0.040404           0.100000                             0
# 3         0.050505           0.100000                             0
# 4         0.070707           0.233333                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
print(extended_train_features.shape)
print(features.shape)
# Out:
# (258477, 69)
# (258477, 68)

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# %%
# Apply PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(features)
print (np.sum(pca.explained_variance_ratio_)) 
print (principalComponents.shape) 
print (labels.shape)
# Out:
# 0.368201260924556
# (258477, 3)
# (258477,)

# %%
# Plot principal components
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal_component_1', 'principal_component_2']) 
principalDf.head()
# Out:
#    principal_component_1  principal_component_2
# 0          277242.417151               0.394545
# 1         -496833.582849               0.005570
# 2         -430716.582849              -0.109562
# 3           65218.417151              -0.313530
# 4         -323719.582849               0.468477

# %%
plt.scatter(principalDf['principal_component_1'], principalDf['principal_component_2'], c=labels)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ### Split data

# %%
train_features, test_features, train_labels, test_labels = train_test_split(principalComponents, labels, test_size = 0.3, random_state = 5, shuffle=True)
print('Shape of data')
print(train_features.shape)
print(train_labels.shape)
print(test_features.shape)
print(test_labels.shape)
print("")
# Out:
# Shape of data
# (3500, 2)
# (3500,)
# (1500, 2)
# (1500,)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
#Training the model

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(train_features, train_labels)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# Predict with trained model
predictions = random_forest.predict(test_features)

# %%
f1 = f1_score(test_labels, predictions, average = 'micro')
print(f1)

# With 20 features: 0.6486666666666666 (5000 samples dataframe)
# Out:
# 0.5833333333333334

# %% [markdown]
# ## Clustering

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering, SpectralClustering, KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score, v_measure_score

# %%
_=plt.figure(figsize=(10, 10))
dendrogram(
    linkage_matrix,
    #color_threshold=4,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=10,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
_=plt.title('Hierarchical Clustering Dendrogram (Ward)')
_=plt.xlabel('sample index')
_=plt.ylabel('distance')
_=plt.tight_layout()

# %% [markdown]
# ### Agglomerative

# %%
cluster_agglomerative = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')  
labels_aggl = cluster_agglomerative.fit_predict(principalComponents)
vmeasure_aggl = v_measure_score(train_labels, labels_aggl)
print(vmeasure_aggl)
# Out:
# 0.003233455195932338

# %%
sp = SpectralClustering(n_clusters=3)
sp.fit(train_features)
labels_spectral = sp.labels_
print(labels_spectral)
# vmeasure_sp = v_measure_score(train_labels, labels_spectral)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/manifold/_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# [0 0 0 ... 0 0 0]
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /usr/local/lib/python3.7/site-packages/sklearn/utils/extmath.py:151: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /usr/local/lib/python3.7/site-packages/sklearn/utils/extmath.py:151: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:304: RuntimeWarning: invalid value encountered in add
#   distances += XX
# /usr/local/lib/python3.7/site-packages/sklearn/utils/extmath.py:151: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# ...
